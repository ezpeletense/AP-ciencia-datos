# %% [markdown]
# # Trabajo Practico N1
# ## Introducción al Desarrollo en Python

# %% [markdown]
# **EJERCICIO 1**
#
# Determinar si un numero ingresado por el usuario es PAR

# %%
numero = int(input('Por favor ingrese un número: '))

def es_par(num):

    if num % 2 == 0:
        return True
    else:
        return False


def pares(num):

    if es_par(num):
        print('El número ingresado es par.')
    else:
        print('El número ingresado es impar.')


pares(numero)
# Out:
# Por favor ingrese un número: 3
# El número ingresado es impar.

# %% [markdown]
# **EJERCICIO 2**
#
# Determinar si un numero ingresado por el usuario esta DENTRO DEL RANGO [1,10] y es par. MUESTRE UN MENSAJE EN CASO CONTRARIO 'NÚMERO FUERA DEL RANGO'

# %%
numero = int(input('Por favor ingrese un número: '))

if numero in range(1, 11):
    pares(numero)
else:
    print('El número ingresado está fuera del rango.')
# Out:
# Por favor ingrese un número: 9
# El número ingresado es impar.

# %% [markdown]
# **EJERCICIO 3 CICLO FOR**
#
#
# Solicitar al usuario que ingrese 10 números. Calcule la suma de todos los números ingresados y  cuente cuántos de ellos son par.

# %%
suma = 0
pares = 0

for i in range(1, 11):
    numero = int(input(f'Por favor ingrese el {i}° número: '))
    suma += numero
    if es_par(numero):
        pares += 1

print(f'La suma de los números ingresados es: {suma}.')
print(f'Se cantidad de números pares ingresados es: {pares}.')
# Out:
# Por favor ingrese el 1° número: 2
# Por favor ingrese el 2° número: 2
# Por favor ingrese el 3° número: 2
# Por favor ingrese el 4° número: 2
# Por favor ingrese el 5° número: 2
# Por favor ingrese el 6° número: 3
# Por favor ingrese el 7° número: 3
# Por favor ingrese el 8° número: 3
# Por favor ingrese el 9° número: 3
# Por favor ingrese el 10° número: 3
# La suma de los números ingresados es: 25.
# Se cantidad de números pares ingresados es: 5.

# %% [markdown]
# **EJERCICIOS 4**
#
# Mostrar todos los números presentes en el rango [56,1230]
# Solicitar al usuario que ingrese el rango [a,b] y muestre todos los números pertenecientes a él.

# %%
def mostrar(a, b):

    for i in range(a, b + 1):
        print(i)

inf = int(input('Por favor ingrese un número: '))
sup = int(input('Por favor ingrese un número: '))

mostrar(56, 1230)
print('*' * 10)
mostrar(inf, sup)
# Out:
# Por favor ingrese un número: 12
# Por favor ingrese un número: 36
# 56
# 57
# 58
# 59
# 60
# 61
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# ...

# %% [markdown]
# **EJERCICIO 5 CICLO WHILE**
#
# Solicitar al usuario que ingrese un número, si es negativo o nulo , solicitar reiteradamente hasta que ingrese un numero positivo.

# %% [markdown]
# chicos, si ingresan un dato nulo (vacio), debo usar un while para que vuelva a pedir lo mismo, pero si es un dato no nulo pasa y el valor lo transfomamos en entero,
# y comparamos si es positivo. Si no lo es hay que pedir otro dato, pero puede ser nulo, entonces habría que hacer todo de nuevo. Por eso llamo en el  **else** a la funcion  **positivo**, para que inicie todo de nuevo.
# recuerden que para ejecutar una funcion hay que llamarla con su nombre y parentesis. Ejemplo: positivo()

# %%
def positivo():

    while True:
        entrada = input('Por favor ingrese un número: ')

        if not entrada.lstrip('-').isdigit():
            print("El número ingresado no es válido. Intente nuevamente.")
            continue

        numero = int(entrada)

        if numero > 0:
            return numero
        else:
            print('El número ingresado no es positivo. Intente nuevamente.')

positivo()
# Out:
# Por favor ingrese un número: 8
# 8

# %% [markdown]
# **EJERCICIO 6**
#
# Solicitar al usuario que ingrese un número, si el número es positivo , solicitar reiteradamente hasta que ingrese un numero negativo. Luego mostrar dicho número si es par, en caso contrario mostrar un mensaje 'número ingresado impar'.

# %%
def negativo():

    while True:
        entrada = input('Por favor ingrese un número negativo: ')

        if not entrada.lstrip('-').isdigit():
            print("El número ingresado no es válido. Intente nuevamente.")
            continue

        numero = int(entrada)

        if numero < 0:
            if es_par(numero):
                return numero
            else:
                print('El número ingresado es impar.')
                break

negativo()
# Out:
# Por favor ingrese un número negativo: -3
# El número ingresado es impar.

# %% [markdown]
# **EJERCICIO 7 VECTORES CON CICLO FOR**
#
# Solicitar al usuario que ingrese la cantidad de elementos del vector.
# Ingresar cada elemento del vector y calcular su promedio.AYUDA: EL PROMEDIO ES LA SUMA DE TODOS LOS NÚMEROS DIVIDO LA CANTIDAD TOTAL.
# Mostrar el vector.

# %%
cant = int(input('Por favor ingrese el número de elementos: '))
vect = []

for i in range(1, cant + 1):

    numero = int(input(f'Por favor ingrese el {i}° número: '))
    vect.append(numero)

prom = sum(vect) / cant


print(f'El promedio de los números es: {prom}.')
print(f'Los números ingresados fueron: {vect}.')
# Out:
# Por favor ingrese el número de elementos: 2
# Por favor ingrese el 1° número: 8
# Por favor ingrese el 2° número: 14
# El promedio de los números es: 11.0.
# Los números ingresados fueron: [8, 14].

# %% [markdown]
# **EJERCICIO 8 LISTA CON CICLO FOR**
#
# Solicitar a 10 usuarios que ingresen los siguientes datos en el formato lista.
#
# ['NOMBRE','APELLIDO', 'DNI','GASTOS MENSUALES DE HOGAR']
#
# Ingresar el final de la lista los siguientes usuarios:
#
# ['ESTEBAN','LOPEZ', '45675400','190800.80']
#
# ['NOELIA','ALEJA', '46906875','85900.50']
#
# Mostrar el vector.
# Eliminar el primer usuario de la lista.

# %% [markdown]
# para probar como funciona cambien en el for el 10 por 2 y ejecuten ingrese los datos que le pidan y al terminar todo vuelvan a poner 10 en el for

# %%
usuarios = []

for i in range(10):

    usuario = []
    nombre = input('Por favor ingrese su nombre: ')
    usuario.append(nombre)

    apellido = input('Por favor ingrese su apellido: ')
    usuario.append(apellido)

    dni = int(input('Por favor ingrese su DNI: '))
    usuario.append(dni)

    gmh = float(input('Por favor ingrese sus Gastos Mensuales: '))
    usuario.append(gmh)

    usuarios.append(usuario)

ejemplo1 = ['Esteban', 'Lopez', '45675400', '190800.80']
usuarios.append(ejemplo1)
ejemplo2 = ['Noelia','Aleja', '46906875','85900.50']
usuarios.append(ejemplo2)


print(*usuarios, sep='\n')

usuarios.pop(0)
# Out:
# Por favor ingrese su nombre: Hector
# Por favor ingrese su apellido: Reyes
# Por favor ingrese su DNI: 10920342
# Por favor ingrese sus Gastos Mensuales: 143799.80
# Por favor ingrese su nombre: Diego
# Por favor ingrese su apellido: Gomez
# Por favor ingrese su DNI: 29034588
# Por favor ingrese sus Gastos Mensuales: 123899.40
# ['Hector', 'Reyes', 10920342, 143799.8]
# ['Diego', 'Gomez', 29034588, 123899.4]
# ['Esteban', 'Lopez', '45675400', '190800.80']
# ['Noelia', 'Aleja', '46906875', '85900.50']
# ['Diego', 'Gomez', 29034588, 123899.4]
# ['Esteban', 'Lopez', '45675400', '190800.80']
# ['Noelia', 'Aleja', '46906875', '85900.50']

# %% [markdown]
# **EJERCICIO 9 LISTA CON CICLO FOR**
#
# Buscar en la web los datos pablacionales de todas las provicias de Argentina , generando una lista con los siguiente información.
#
# ['PROVINCIA','CANTIDAD DE HABITANTES', 'CONSUMO ELECTRICO PER CAPITA','SUPERFICIE EN M^2']
#
#
#
# Mostrar TODOS LOS DATOS DEL LISTADO.

# %%
datos_provincias = [
    ['Buenos Aires', 17_541_141, 's/d', 307_571],
    ['Catamarca', 415_438, 's/d', 102_602],
    ['Chaco', 1_204_541, 's/d', 99_603],
    ['Chubut', 618_994, 's/d', 224_686],
    ['Córdoba', 3_760_450, 's/d', 165_321],
    ['Corrientes', 1_120_801, 's/d', 88_199],
    ['Entre Ríos', 1_385_961, 's/d', 78_781],
    ['Formosa', 605_193, 's/d', 72_066],
    ['Jujuy', 770_881, 's/d', 53_219],
    ['La Pampa', 358_428, 's/d', 143_440],
    ['La Rioja', 393_531, 's/d', 89_680],
    ['Mendoza', 1_990_338, 's/d', 148_827],
    ['Misiones', 1_261_294, 's/d', 29_801],
    ['Neuquen', 664_057, 's/d', 94_078],
    ['Río Negro', 747_610, 's/d', 203_013],
    ['Salta', 1_424_397, 's/d', 155_488],
    ['San Juan', 781_217, 's/d', 89_651],
    ['San Luís', 508_328, 's/d', 76_748],
    ['Santa Cruz', 365_698, 's/d', 243_934],
    ['Santa Fe', 3_536_418, 's/d', 133_007],
    ['Santiago del Estero', 978_313, 's/d', 136_351],
    ['Tierra del Fuego, Antártida e Islas del Atlántico Sur', 173_432, 's/d', 21_571],
    ['Tucumán', 1_694_656, 's/d', 22_524],
    ['Ciudad Autónoma de Buenos Aires', 3_075_646, 's/d', 203],
]

print('Provincia | Habitantes | Consumo eléctrico per capita | Superficie en km²')
#print(*datos_provincias, sep='\n')
for provincia, habitantes, consumo, superficie in datos_provincias:
    print(f'{provincia} | {habitantes} | {consumo} | {superficie}')
# Out:
# Provincia | Habitantes | Consumo eléctrico per capita | Superficie en km²
# Buenos Aires | 17541141 | s/d | 307571
# Catamarca | 415438 | s/d | 102602
# Chaco | 1204541 | s/d | 99603
# Chubut | 618994 | s/d | 224686
# Córdoba | 3760450 | s/d | 165321
# Corrientes | 1120801 | s/d | 88199
# Entre Ríos | 1385961 | s/d | 78781
# Formosa | 605193 | s/d | 72066
# Jujuy | 770881 | s/d | 53219
# La Pampa | 358428 | s/d | 143440
# La Rioja | 393531 | s/d | 89680
# Mendoza | 1990338 | s/d | 148827
# Misiones | 1261294 | s/d | 29801
# Neuquen | 664057 | s/d | 94078
# Río Negro | 747610 | s/d | 203013
# Salta | 1424397 | s/d | 155488
# San Juan | 781217 | s/d | 89651
# San Luís | 508328 | s/d | 76748
# Santa Cruz | 365698 | s/d | 243934
# Santa Fe | 3536418 | s/d | 133007
# Santiago del Estero | 978313 | s/d | 136351
# Tierra del Fuego, Antártida e Islas del Atlántico Sur | 173432 | s/d | 21571
# Tucumán | 1694656 | s/d | 22524
# Ciudad Autónoma de Buenos Aires | 3075646 | s/d | 203

# %% [markdown]
# **EJERCICIO 10 LISTAS**
#
# Crear una lista con información de estudianes de un colegio donde incluya los siguientes items:
#
#
# *   curso y división del aula del alumno
# *   nombre y apellidos
# *   DNI
# *   cantidad de notas en el primer trimestre
# *   INGRESAR CADA UNA DE ESAS NOTAS, POR EL USUARIO
# *   promedio del trimestre
#
# Mostrar todos los nombres y apellidos de los  alumnos
# Mostrar los alumnos con promedio mayor o igual a 6

# %%
datos_alumnos = [
    ['1º2º','Pablo Fernandez', 40_987_032,
     {'Matemáticas': 5, 'Cs. Sociales': 8,'Literatura' : 5}, 6],
    ['1º1º','María Gomez', 41_089_122,
     {'Matemáticas': 5, 'Cs. Sociales': 6,'Literatura' : 2}, 4.33],
    ['2º1º','Andrea Hernandez', 40_127_991,
     {'Matemáticas': 10, 'Cs. Sociales': 8,'Literatura' : 8}, 8.66],
    ['1º2º','Juan Nieve', 41_537_009,
     {'Matemáticas': 4, 'Cs. Sociales': 3,'Literatura' : 3}, 3.33],
]

# mostrar los nombres y apellidos
print('~~ Listado de alumnos ~~')
for alumno in datos_alumnos:
    print(alumno[1])

# mostrar los nombres, apellidos y promedios, si el promedio es mayor a 6
print('~~ Listado de alumnos con promedio mayor o igual a 6 ~~')
for alumno in datos_alumnos:
    if alumno[-1] >= 6:
        print(alumno[1], 'Promedio:', alumno[-1])
# Out:
# ~~ Listado de alumnos ~~
# Pablo Fernandez
# María Gomez
# Andrea Hernandez
# Juan Nieve
# ~~ Listado de alumnos con promedio mayor o igual a 6 ~~
# Pablo Fernandez Promedio: 6
# Andrea Hernandez Promedio: 8.66
